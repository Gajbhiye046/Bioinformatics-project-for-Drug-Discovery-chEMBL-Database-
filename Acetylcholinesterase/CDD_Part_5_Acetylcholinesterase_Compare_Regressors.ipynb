# %% [markdown]
# # **Computational Drug Discovery : Comparing Regressors**
#
# In Step 5, we will be comparing several ML algorithms for build regression models of acetylcholinesterase inhibitors.

# %% [markdown]
# ## **1. Import libraries**

# %%
! pip install lazypredict
# Out:
# Collecting lazypredict
#   Downloading https://files.pythonhosted.org/packages/5f/db/1566dca1050ea74e9474dca0f1e7bbffcb0c3e694cf92e7e6e7ef9fca3af/lazypredict-0.2.7-py2.py3-none-any.whl
# Requirement already satisfied: Click>=7.0 in /usr/local/lib/python3.6/dist-packages (from lazypredict) (7.1.2)
# Installing collected packages: lazypredict
# Successfully installed lazypredict-0.2.7

# %%
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
import lazypredict
from lazypredict.Supervised import LazyRegressor
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:143: FutureWarning: The sklearn.utils.testing module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.utils. Anything that cannot be imported from sklearn.utils is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %% [markdown]
# ## **2. Load the data set**

# %%
df = pd.read_csv('acetylcholinesterase_05_bioactivity_data_3class_pIC50_pubchem_fp.csv')

# %%
X = df.drop('pIC50', axis=1)
Y = df.pIC50

# %% [markdown]
# ## **3. Data pre-processing**

# %%
# Examine X dimension
X.shape
# Out:
# (5103, 881)

# %%
# Remove low variance features
from sklearn.feature_selection import VarianceThreshold
selection = VarianceThreshold(threshold=(.8 * (1 - .8)))    
X = selection.fit_transform(X)
X.shape
# Out:
# (5103, 140)

# %%
# Perform data splitting using 80/20 ratio
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %% [markdown]
# ## **4. Compare ML algorithms**

# %%
# Defines and builds the lazyclassifier
clf = LazyRegressor(verbose=0,ignore_warnings=True, custom_metric=None)
models,predictions = clf.fit(X_train, X_test, Y_train, Y_test)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 42/42 [01:13<00:00,  1.75s/it]

# %%
# Performance table of the training set (80% subset)
predictions
# Out:
#                                       Adjusted R-Squared  \
# Model
# RandomForestRegressor                               0.63
# HistGradientBoostingRegressor                       0.61
# LGBMRegressor                                       0.61
# BaggingRegressor                                    0.61
# XGBRegressor                                        0.60
# MLPRegressor                                        0.56
# SVR                                                 0.54
# KNeighborsRegressor                                 0.54
# NuSVR                                               0.53
# ExtraTreesRegressor                                 0.47
# GradientBoostingRegressor                           0.45
# DecisionTreeRegressor                               0.43
# ExtraTreeRegressor                                  0.43
# RidgeCV                                             0.30
# LassoCV                                             0.30
# ElasticNetCV                                        0.30
# LassoLarsCV                                         0.30
# Ridge                                               0.30
# BayesianRidge                                       0.29
# LassoLarsIC                                         0.29
# TransformedTargetRegressor                          0.28
# LinearRegression                                    0.28
# HuberRegressor                                      0.28
# SGDRegressor                                        0.28
# PoissonRegressor                                    0.26
# LinearSVR                                           0.25
# OrthogonalMatchingPursuit                           0.20
# OrthogonalMatchingPursuitCV                         0.20
# TweedieRegressor                                    0.19
# GeneralizedLinearRegressor                          0.19
# GammaRegressor                                      0.18
# AdaBoostRegressor                                   0.13
# LarsCV                                              0.06
# Lasso                                              -0.16
# ElasticNet                                         -0.16
# DummyRegressor                                     -0.16
# LassoLars                                          -0.16
# PassiveAggressiveRegressor                         -0.46
# GaussianProcessRegressor                           -6.03
# KernelRidge                                       -15.44
# Lars                                             -220.66
# RANSACRegressor               -2052548066884017717248.00
#
#                                                R-Squared           RMSE  \
# Model
# RandomForestRegressor                               0.68           0.91
# HistGradientBoostingRegressor                       0.67           0.92
# LGBMRegressor                                       0.67           0.92
# BaggingRegressor                                    0.67           0.93
# XGBRegressor                                        0.65           0.94
# MLPRegressor                                        0.62           0.99
# SVR                                                 0.60           1.01
# KNeighborsRegressor                                 0.60           1.01
# NuSVR                                               0.59           1.02
# ExtraTreesRegressor                                 0.54           1.08
# GradientBoostingRegressor                           0.53           1.10
# DecisionTreeRegressor                               0.51           1.12
# ExtraTreeRegressor                                  0.51           1.13
# RidgeCV                                             0.40           1.24
# LassoCV                                             0.39           1.25
# ElasticNetCV                                        0.39           1.25
# LassoLarsCV                                         0.39           1.25
# Ridge                                               0.39           1.25
# BayesianRidge                                       0.39           1.25
# LassoLarsIC                                         0.39           1.25
# TransformedTargetRegressor                          0.38           1.26
# LinearRegression                                    0.38           1.26
# HuberRegressor                                      0.38           1.26
# SGDRegressor                                        0.38           1.26
# PoissonRegressor                                    0.36           1.28
# LinearSVR                                           0.35           1.29
# OrthogonalMatchingPursuit                           0.31           1.33
# OrthogonalMatchingPursuitCV                         0.31           1.33
# TweedieRegressor                                    0.30           1.34
# GeneralizedLinearRegressor                          0.30           1.34
# GammaRegressor                                      0.30           1.34
# AdaBoostRegressor                                   0.25           1.39
# LarsCV                                              0.19           1.44
# Lasso                                              -0.00           1.60
# ElasticNet                                         -0.00           1.60
# DummyRegressor                                     -0.00           1.60
# LassoLars                                          -0.00           1.60
# PassiveAggressiveRegressor                         -0.26           1.80
# GaussianProcessRegressor                           -5.06           3.94
# KernelRidge                                       -13.19           6.03
# Lars                                             -190.24          22.14
# RANSACRegressor               -1770825783194054295552.00 67357082734.64
#
#                                Time Taken
# Model
# RandomForestRegressor                5.82
# HistGradientBoostingRegressor        7.74
# LGBMRegressor                        0.49
# BaggingRegressor                     0.74
# XGBRegressor                         3.24
# MLPRegressor                        11.89
# SVR                                  4.19
# KNeighborsRegressor                  1.48
# NuSVR                                3.32
# ExtraTreesRegressor                  8.37
# GradientBoostingRegressor            2.27
# DecisionTreeRegressor                0.16
# ExtraTreeRegressor                   0.17
# RidgeCV                              0.18
# LassoCV                              3.50
# ElasticNetCV                         3.45
# LassoLarsCV                          0.52
# Ridge                                0.08
# BayesianRidge                        0.18
# LassoLarsIC                          0.16
# TransformedTargetRegressor           0.13
# LinearRegression                     0.13
# HuberRegressor                       0.78
# SGDRegressor                         0.12
# PoissonRegressor                     0.13
# LinearSVR                            1.00
# OrthogonalMatchingPursuit            0.07
# OrthogonalMatchingPursuitCV          0.21
# TweedieRegressor                     0.09
# GeneralizedLinearRegressor           0.09
# GammaRegressor                       0.10
# AdaBoostRegressor                    1.52
# LarsCV                               0.53
# Lasso                                0.08
# ElasticNet                           0.07
# DummyRegressor                       0.07
# LassoLars                            0.08
# PassiveAggressiveRegressor           0.09
# GaussianProcessRegressor             6.67
# KernelRidge                          1.76
# Lars                                 0.13
# RANSACRegressor                      1.71

# %% [markdown]
# ## **5. Data visualization of model performance**

# %% [raw]
# - if R-squared value < 0.3 this value is generally considered a None or Very weak effect size,
# - if R-squared value 0.3 < r < 0.5 this value is generally considered a weak or low effect size,
# - if R-squared value r > 0.7 this value is generally considered strong effect size.

# %%
# Bar plot of R-squared values
import matplotlib.pyplot as plt
import seaborn as sns

#train["R-Squared"] = [0 if i < 0 else i for i in train.iloc[:,0] ]

plt.figure(figsize=(5, 10))
sns.set_theme(style="whitegrid")
ax = sns.barplot(y=predictions.index, x="R-Squared", data=predictions)
ax.set(xlim=(0, 1))
# Out:
# [(0.0, 1.0)]

# %% [raw]
# Root Mean Square Error (RMSE) is the standard deviation of the residuals (prediction errors).
# Based on a rule of thumb, it can be said that RMSE values between 0.2 and 0.5 shows that the model can relatively predict the data accurately. In addition, Adjusted R-squared more than 0.75 is a very good value for showing the accuracy. In some cases, Adjusted R-squared of 0.4 or more is acceptable as well.

# %%
# Bar plot of RMSE values
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(5, 10))
sns.set_theme(style="whitegrid")
ax = sns.barplot(y=predictions.index, x="RMSE", data=predictions)
ax.set(xlim=(0, 10))
# Out:
# [(0.0, 10.0)]

# %%
# Bar plot of calculation time
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(5, 10))
sns.set_theme(style="whitegrid")
ax = sns.barplot(y=predictions.index, x="Time Taken", data=predictions)
ax.set(xlim=(0, 10))
# Out:
# [(0.0, 10.0)]
